# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("qmarva/cubicasa5k")

print(r"C:\Users\kdgki\Desktop\MSCDP\Projects\neural_floorplan\docs\original_vector", path)
# Out:
# ...
# 100%|██████████| 5.10G/5.10G [13:44<00:00, 6.65MB/s]
# Extracting files...
# C:\Users\kdgki\Desktop\MSCDP\Projects\neural_floorplan\docs\original_vector C:\Users\kdgki\.cache\kagglehub\datasets\qmarva\cubicasa5k\versions\4
